# %%
# Run this cell and restart your jupyter kernel
#!pip install -U scikit-learn

# %%
import sklearn
print(sklearn.__version__) # Must print version 1.0
# Out:
# 1.0

# %%
import pandas as pd

import matplotlib.pyplot as plt

import numpy as np
import scipy

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('data/dataset_Facebook.csv')
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0     0.0                       2752                             5091
# 1     0.0                      10460                            19057
# 2     0.0                       2413                             4373
# 3     1.0                      50128                            87991
# 4     0.0                       7244                            13594
# ..    ...                        ...                              ...
# 495   0.0                       4684                             7536
# 496   0.0                       3480                             6229
# 497   0.0                       3778                             7216
# 498   0.0                       4156                             7564
# 499   NaN                       4188                             7292
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# 0                       178                      109
# 1                      1457                     1361
# 2                       177                      113
# 3                      2211                      790
# 4                       671                      410
# ..                      ...                      ...
# 495                     733                      708
# 496                     537                      508
# 497                     625                      572
# 498                     626                      574
# 499                     564                      524
#
#      Lifetime Post Consumptions  \
# 0                           159
# 1                          1674
# 2                           154
# 3                          1119
# 4                           580
# ..                          ...
# 495                         985
# 496                         687
# 497                         795
# 498                         832
# 499                         743
#
#      Lifetime Post Impressions by people who have liked your Page  \
# 0                                                 3078
# 1                                                11710
# 2                                                 2812
# 3                                                61027
# 4                                                 6228
# ..                                                 ...
# 495                                               4750
# 496                                               3961
# 497                                               4742
# 498                                               4534
# 499                                               3861
#
#      Lifetime Post reach by people who like your Page  \
# 0                                                1640
# 1                                                6112
# 2                                                1503
# 3                                               32048
# 4                                                3200
# ..                                                ...
# 495                                              2876
# 496                                              2104
# 497                                              2388
# 498                                              2452
# 499                                              2200
#
#      Lifetime People who have liked your Page and engaged with your post  \
# 0                                                  119
# 1                                                 1108
# 2                                                  132
# 3                                                 1386
# 4                                                  396
# ..                                                 ...
# 495                                                392
# 496                                                301
# 497                                                363
# 498                                                370
# 499                                                316
#
#      comment    like  share  Total Interactions
# 0          4    79.0   17.0                 100
# 1          5   130.0   29.0                 164
# 2          0    66.0   14.0                  80
# 3         58  1572.0  147.0                1777
# 4         19   325.0   49.0                 393
# ..       ...     ...    ...                 ...
# 495        5    53.0   26.0                  84
# 496        0    53.0   22.0                  75
# 497        4    93.0   18.0                 115
# 498        7    91.0   38.0                 136
# 499        0    91.0   28.0                 119
#
# [500 rows x 19 columns]

# %% [markdown]
# # Sanity Verification
# ## Missing Values

# %%
###################
# INSERT CODE HERE
###################
## TODO: deal with NaN values

df = df.dropna()
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 494             85093   Photo         3           1             7         10
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0     0.0                       2752                             5091
# 1     0.0                      10460                            19057
# 2     0.0                       2413                             4373
# 3     1.0                      50128                            87991
# 4     0.0                       7244                            13594
# ..    ...                        ...                              ...
# 494   0.0                       5400                             9218
# 495   0.0                       4684                             7536
# 496   0.0                       3480                             6229
# 497   0.0                       3778                             7216
# 498   0.0                       4156                             7564
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# 0                       178                      109
# 1                      1457                     1361
# 2                       177                      113
# 3                      2211                      790
# 4                       671                      410
# ..                      ...                      ...
# 494                     810                      756
# 495                     733                      708
# 496                     537                      508
# 497                     625                      572
# 498                     626                      574
#
#      Lifetime Post Consumptions  \
# 0                           159
# 1                          1674
# 2                           154
# 3                          1119
# 4                           580
# ..                          ...
# 494                        1003
# 495                         985
# 496                         687
# 497                         795
# 498                         832
#
#      Lifetime Post Impressions by people who have liked your Page  \
# 0                                                 3078
# 1                                                11710
# 2                                                 2812
# 3                                                61027
# 4                                                 6228
# ..                                                 ...
# 494                                               5654
# 495                                               4750
# 496                                               3961
# 497                                               4742
# 498                                               4534
#
#      Lifetime Post reach by people who like your Page  \
# 0                                                1640
# 1                                                6112
# 2                                                1503
# 3                                               32048
# 4                                                3200
# ..                                                ...
# 494                                              3230
# 495                                              2876
# 496                                              2104
# 497                                              2388
# 498                                              2452
#
#      Lifetime People who have liked your Page and engaged with your post  \
# 0                                                  119
# 1                                                 1108
# 2                                                  132
# 3                                                 1386
# 4                                                  396
# ..                                                 ...
# 494                                                422
# 495                                                392
# 496                                                301
# 497                                                363
# 498                                                370
#
#      comment    like  share  Total Interactions
# 0          4    79.0   17.0                 100
# 1          5   130.0   29.0                 164
# 2          0    66.0   14.0                  80
# 3         58  1572.0  147.0                1777
# 4         19   325.0   49.0                 393
# ..       ...     ...    ...                 ...
# 494       10   125.0   41.0                 176
# 495        5    53.0   26.0                  84
# 496        0    53.0   22.0                  75
# 497        4    93.0   18.0                 115
# 498        7    91.0   38.0                 136
#
# [495 rows x 19 columns]

# %% [markdown]
# ## Data Format

# %%
##### # INSERT CODE HERE
###################
## TODO: Handle categorigal features


for i, value in enumerate(df["Type"].unique()):
    df.loc[df["Type"]==value, "Type"] = i
    
df
# Out:
# /home/thomas/.local/lib/python3.8/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
#      Page total likes Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441    0         2          12             4          3
# 1              139441    1         2          12             3         10
# 2              139441    0         3          12             3          3
# 3              139441    0         2          12             2         10
# 4              139441    0         2          12             2          3
# ..                ...  ...       ...         ...           ...        ...
# 494             85093    0         3           1             7         10
# 495             85093    0         3           1             7          2
# 496             81370    0         2           1             5          8
# 497             81370    0         1           1             5          2
# 498             81370    0         3           1             4         11
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0     0.0                       2752                             5091
# 1     0.0                      10460                            19057
# 2     0.0                       2413                             4373
# 3     1.0                      50128                            87991
# 4     0.0                       7244                            13594
# ..    ...                        ...                              ...
# 494   0.0                       5400                             9218
# 495   0.0                       4684                             7536
# 496   0.0                       3480                             6229
# 497   0.0                       3778                             7216
# 498   0.0                       4156                             7564
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# 0                       178                      109
# 1                      1457                     1361
# 2                       177                      113
# 3                      2211                      790
# 4                       671                      410
# ..                      ...                      ...
# 494                     810                      756
# 495                     733                      708
# 496                     537                      508
# 497                     625                      572
# 498                     626                      574
#
#      Lifetime Post Consumptions  \
# 0                           159
# 1                          1674
# 2                           154
# 3                          1119
# 4                           580
# ..                          ...
# 494                        1003
# 495                         985
# 496                         687
# 497                         795
# 498                         832
#
#      Lifetime Post Impressions by people who have liked your Page  \
# 0                                                 3078
# 1                                                11710
# 2                                                 2812
# 3                                                61027
# 4                                                 6228
# ..                                                 ...
# 494                                               5654
# 495                                               4750
# 496                                               3961
# 497                                               4742
# 498                                               4534
#
#      Lifetime Post reach by people who like your Page  \
# 0                                                1640
# 1                                                6112
# 2                                                1503
# 3                                               32048
# 4                                                3200
# ..                                                ...
# 494                                              3230
# 495                                              2876
# 496                                              2104
# 497                                              2388
# 498                                              2452
#
#      Lifetime People who have liked your Page and engaged with your post  \
# 0                                                  119
# 1                                                 1108
# 2                                                  132
# 3                                                 1386
# 4                                                  396
# ..                                                 ...
# 494                                                422
# 495                                                392
# 496                                                301
# 497                                                363
# 498                                                370
#
#      comment    like  share  Total Interactions
# 0          4    79.0   17.0                 100
# 1          5   130.0   29.0                 164
# 2          0    66.0   14.0                  80
# 3         58  1572.0  147.0                1777
# 4         19   325.0   49.0                 393
# ..       ...     ...    ...                 ...
# 494       10   125.0   41.0                 176
# 495        5    53.0   26.0                  84
# 496        0    53.0   22.0                  75
# 497        4    93.0   18.0                 115
# 498        7    91.0   38.0                 136
#
# [495 rows x 19 columns]

# %% [markdown]
# ## Outlier Removal

# %%
fig=plt.figure(figsize=(10, 10), dpi=90)
n_feats = len(df.columns)
for i, feat in enumerate(df.columns[:-1]):
    plt.subplot(n_feats//3+1,3,i+1)
    plt.scatter(df[feat],df['Total Interactions'], s=10)
#     plt.title(feat)
plt.tight_layout()
plt.show()

# %%
###################
# INSERT CODE HERE
###################
## TODO: Remove the samples containing outliers

df["Type"] = df["Type"].astype("int64")
df = df[(np.abs(scipy.stats.zscore(df)) < 3).all(axis=1)]
# Out:
# <ipython-input-191-8e027214e430>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Type"] = df["Type"].astype("int64")

# %%
fig=plt.figure(figsize=(10, 10), dpi=90)
n_feats = len(df.columns)
for i, feat in enumerate(df.columns[:-1]):
    plt.subplot(n_feats//3+1,3,i+1)
    plt.scatter(df[feat],df['Total Interactions'], s=10)
#     plt.title(feat)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Redundancy verification + Relevance verification

# %%
plt.figure(figsize=(20,20))
cor = df.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()
"Influence sur le KNN regressor et sur le linear regressor : C'est mauvais parce que avec une dimension en plus, il y a bcp plus de calcul et que nous ne gagnons pas d'information sur cela. De plus on donne un plus gros poids à la même information ce qui va biaiser le model."
# Out:
# "Influence sur le KNN regressor et sur le linear regressor : C'est mauvais parce que avec une dimension en plus, il y a bcp plus de calcul et que nous ne gagnons pas d'information sur cela. De plus on donne un plus gros poids à la même information ce qui va biaiser le model."

# %% [markdown]
# # Balance of Influences

# %%
df
# Out:
#      Page total likes  Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441     0         2          12             4          3
# 1              139441     1         2          12             3         10
# 2              139441     0         3          12             3          3
# 4              139441     0         2          12             2          3
# 5              139441     1         2          12             1          9
# ..                ...   ...       ...         ...           ...        ...
# 494             85093     0         3           1             7         10
# 495             85093     0         3           1             7          2
# 496             81370     0         2           1             5          8
# 497             81370     0         1           1             5          2
# 498             81370     0         3           1             4         11
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0     0.0                       2752                             5091
# 1     0.0                      10460                            19057
# 2     0.0                       2413                             4373
# 4     0.0                       7244                            13594
# 5     0.0                      10472                            20849
# ..    ...                        ...                              ...
# 494   0.0                       5400                             9218
# 495   0.0                       4684                             7536
# 496   0.0                       3480                             6229
# 497   0.0                       3778                             7216
# 498   0.0                       4156                             7564
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# 0                       178                      109
# 1                      1457                     1361
# 2                       177                      113
# 4                       671                      410
# 5                      1191                     1073
# ..                      ...                      ...
# 494                     810                      756
# 495                     733                      708
# 496                     537                      508
# 497                     625                      572
# 498                     626                      574
#
#      Lifetime Post Consumptions  \
# 0                           159
# 1                          1674
# 2                           154
# 4                           580
# 5                          1389
# ..                          ...
# 494                        1003
# 495                         985
# 496                         687
# 497                         795
# 498                         832
#
#      Lifetime Post Impressions by people who have liked your Page  \
# 0                                                 3078
# 1                                                11710
# 2                                                 2812
# 4                                                 6228
# 5                                                16034
# ..                                                 ...
# 494                                               5654
# 495                                               4750
# 496                                               3961
# 497                                               4742
# 498                                               4534
#
#      Lifetime Post reach by people who like your Page  \
# 0                                                1640
# 1                                                6112
# 2                                                1503
# 4                                                3200
# 5                                                7852
# ..                                                ...
# 494                                              3230
# 495                                              2876
# 496                                              2104
# 497                                              2388
# 498                                              2452
#
#      Lifetime People who have liked your Page and engaged with your post  \
# 0                                                  119
# 1                                                 1108
# 2                                                  132
# 4                                                  396
# 5                                                 1016
# ..                                                 ...
# 494                                                422
# 495                                                392
# 496                                                301
# 497                                                363
# 498                                                370
#
#      comment   like  share  Total Interactions
# 0          4   79.0   17.0                 100
# 1          5  130.0   29.0                 164
# 2          0   66.0   14.0                  80
# 4         19  325.0   49.0                 393
# 5          1  152.0   33.0                 186
# ..       ...    ...    ...                 ...
# 494       10  125.0   41.0                 176
# 495        5   53.0   26.0                  84
# 496        0   53.0   22.0                  75
# 497        4   93.0   18.0                 115
# 498        7   91.0   38.0                 136
#
# [422 rows x 19 columns]

# %%
# build the input data and target
X = df.drop("Total Interactions",1)    #Feature Matrix
Y = df["Total Interactions"]           #Target Variable

# %%
###################
# INSERT CODE HERE
###################
## TODO:  TRAIN-TEST splitting
# X_train, X_test, y_train, y_test = ...

X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X, Y, test_size=0.30, random_state=42)

# %%
print(f'Training Samples shape: {X_train.shape} ; Training Target shape: {y_train.shape}\nTest Samples shape: {X_test.shape}; Test Target shape {y_test.shape}')
# Out:
# Training Samples shape: (295, 18) ; Training Target shape: (295,)
# Test Samples shape: (127, 18); Test Target shape (127,)

# %%
# Compute the Root Mean Square Error
def compute_rmse(predict, target):
    ###################
    # INSERT CODE HERE
    ###################
    #Facon avec norme carré mais enfaite c'est norme (donc absolute value)
    P = len(target)
#     summ = 0
#     for i in range(P):
#         summ += (target[i] - predict[i]) ** 2
#     return np.sqrt((1/P) * summ)
    if len(target.shape) == 2:
        target = target.squeeze()
    if len(predict.shape) == 2:
        predict = predict.squeeze()
    diff = target - predict
    if len(diff.shape) == 1:
        diff = np.expand_dims(diff, axis=-1)
    rmse = np.sqrt(diff.T@diff / diff.shape[0])
    return float(rmse)

# %%
def fit_predict_with_features(X_train,Y_train, X_test, selected_features):
    ###################
    # INSERT CODE HERE
    ###################
    ## TODO:
    # Filter X_train and X_test features
    # Create linear regressor + fit on train data + predict on test data
    ####
    reg = LinearRegression().fit(X_train[selected_features], Y_train)
    
    y_pred = reg.predict(X_test[selected_features])

    return y_pred

# %%
print('RMSE Without FS (feature selection)')
y_pred = fit_predict_with_features(X_train,y_train, X_test, X_train.columns)
print(compute_rmse(y_pred, y_test.to_numpy()))
# Out:
# RMSE Without FS (feature selection)
# 2.409679655387187e-13

# %% [markdown]
# # Filter

# %%
# keep only the features with high correlation
###################
# INSERT CODE HERE
###################
## TODO: Define a threshold and filter out the features with corr < thresh
# create a variable named relevant_features containing a pandas series with the features to keep.
######
    
tresh = 0.50
corr = df.corr()
corr = np.abs(corr["Total Interactions"])
relevant_features = corr[corr > tresh]

rf = [k for k,v in relevant_features.items() if k != 'Total Interactions']
print(rf)

# df = df[(np.abs(scipy.stats.zscore(df)) < 3).all(axis=1)]
# Out:
# ['Lifetime Post Total Reach', 'Lifetime Engaged Users', 'Lifetime Post reach by people who like your Page', 'comment', 'like', 'share']

# %%
y_pred = fit_predict_with_features(X_train,y_train, X_test, rf)

print('RMSE after Filter')
print(compute_rmse(y_pred, y_test.to_numpy()))
# Out:
# RMSE after Filter
# 1.107985502426071e-12

# %% [markdown]
# # Wrapper method

# %%
# For this last part, you are expected to use the implementation of Forward and Backward Wrapper
# methods provided in the sklearn.feature selection module. Then, for each selection method,
# train a linear model and compare their performances (RMSE) with respect to the baseline model.

# Forward

n_feats = 6
cols = list(X_train.columns)

###################
# INSERT CODE HERE
###################
## TODO: create new linear regressor + Use SFS in forward mode
####################
new_reg = LinearRegression()
sfs = sklearn.feature_selection.SequentialFeatureSelector(new_reg, n_features_to_select=n_feats, direction="forward")
sfs.fit(X, Y)

temp = pd.Series(sfs.support_,index = cols)
selected_features_sfs_forward = temp[temp==True].index
print(selected_features_sfs_forward)
# Out:
# Index(['Page total likes', 'Type', 'Category', 'comment', 'like', 'share'], dtype='object')

# %%
y_pred = fit_predict_with_features(X_train,y_train, X_test, selected_features_sfs_forward)

print('RMSE with wrapper Forward')
print(compute_rmse(y_pred, y_test.to_numpy()))
# Out:
# RMSE with wrapper Forward
# 1.3611460651422791e-11

# %%
# Backward
###################
# INSERT CODE HERE
###################
## TODO: create new linear regressor + Use SFS in backward mode
#################### 
new_reg = LinearRegression()
sfs = sklearn.feature_selection.SequentialFeatureSelector(new_reg, n_features_to_select=n_feats, direction="backward")
sfs.fit(X, Y)

temp = pd.Series(sfs.support_,index = cols)
selected_features_sfs_backward = temp[temp==True].index
print(selected_features_sfs_backward)
# Out:
# Index(['Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share'],
#       dtype='object')

# %%
y_pred = fit_predict_with_features(X_train,y_train, X_test, selected_features_sfs_backward)

print('RMSE with wrapper Backward')
print(compute_rmse(y_pred, y_test.to_numpy()))
# Out:
# RMSE with wrapper Backward
# 1.25500875811541e-12
